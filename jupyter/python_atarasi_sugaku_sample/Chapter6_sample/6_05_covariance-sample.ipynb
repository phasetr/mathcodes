# %% [markdown]
# ▲リスト6.18：共分散とデータの傾向

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
 
x = np.array([50, 70, 40, 60, 80])  # 数学の点数
y = np.array([60, 80, 50, 50, 70])  # 英語の点数
z = np.array([60, 40, 60, 40, 30])  # 国語の点数

cov_xy = np.average((x-np.average(x))*(y-np.average(y)))
print("cov_xy", cov_xy)

cov_xz = np.average((x-np.average(x))*(z-np.average(z)))
print("cov_xz", cov_xz)

plt.scatter(x, y, marker="o", label="xy", s=40)  # sはマーカーのサイズ
plt.scatter(x, z, marker="x", label="xz", s=60)
plt.legend()

plt.xlabel("x", size=14)
plt.ylabel("y", size=14)
plt.grid()

plt.show()
# Out:
# cov_xy 120.0
# cov_xz -160.0

# %% [markdown]
# ▲リスト6.19：共分散からデータを生成する

# %%
import numpy as np
import matplotlib.pyplot as plt

def show_cov(cov):
    print("--- Covariance:", cov, " ---")
    average = np.array([0, 0])  # xとyのそれぞれの平均
    cov_matrix = np.array([[1, cov],  # 共分散を行列で指定
                           [cov, 1]])
    
    # 共分散からペアのデータを3000組生成。dataは(3000, 2)の形状の行列になる
    data = np.random.multivariate_normal(average, cov_matrix, 3000)
    x = data[:, 0]  # 最初の列をx座標に
    y = data[:, 1]  # 次の列をy座標に
    
    plt.scatter(x, y, marker="x", s=20)
    
    plt.xlabel("x", size=14)
    plt.ylabel("y", size=14)
    plt.grid()

    plt.show()

show_cov(0.6)  # 共分散: 0.6
show_cov(0.0)  # 共分散: 0.0
show_cov(-0.6)  # 共分散: -0.6
# Out:
# --- Covariance: 0.6  ---
# --- Covariance: 0.0  ---
# --- Covariance: -0.6  ---

# %% [markdown]
# #### □問題
# 　リスト6.20を補完し、世界史と日本史の点数の共分散を求めましょう。

# %% [markdown]
# ▲リスト6.20：問題

# %%
import numpy as np
import matplotlib.pyplot as plt
 
x = np.array([30, 70, 40, 60, 90])  # 世界史の点数
y = np.array([20, 60, 50, 40, 80])  # 日本史の点数

cov_xy =     # （ここにコードを書く）共分散
print("--- cov_xy ---", cov_xy)

plt.scatter(x, y, marker="o", label="xy", s=40)
plt.legend()

plt.xlabel("x", size=14)
plt.ylabel("y", size=14)
plt.grid()

plt.show()

# %% [markdown]
# #### □解答例

# %% [markdown]
# ▲リスト6.21：解答例

# %%
import numpy as np
import matplotlib.pyplot as plt
 
x = np.array([30, 70, 40, 60, 90])  # 世界史の点数
y = np.array([20, 60, 50, 40, 80])  # 日本史の点数

cov_xy = np.average((x-np.average(x))*(y-np.average(y)))  # （ここにコードを書く）共分散
print("cov_xy", cov_xy)

plt.scatter(x, y, marker="o", label="xy", s=40)
plt.legend()

plt.xlabel("x", size=14)
plt.ylabel("y", size=14)
plt.grid()

plt.show()
# Out:
# cov_xy 380.0
